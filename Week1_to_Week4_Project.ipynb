# %%
print("Data Science Internship - Month 1")
# Out:
# Data Science Internship - Month 1

# %%
name = "Anushree"
age = 22
cgpa = 8.5

print("Name:", name)
print("Age:", age)
print("CGPA:", cgpa)
# Out:
# Name: Anushree
# Age: 22
# CGPA: 8.5

# %%
marks = 85

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
for i in range(1, 6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
celsius = 37

fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Temperature in Fahrenheit: 98.6

# %%
a = 10
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %% [markdown]
# # Week 1 Summary
#
# Topics Learned
#
# - Python Variables
# - Data Types
# - Operators
# - Input and Output
# - Conditional Statements
# - Loops
# - Temperature Converter Program
# - Calculator Program

# %% [markdown]
# # Week 2 - Data Structures and Functions

# %%
fruits = ["Apple", "Banana", "Mango", "Orange"]

print("Fruit List:")
print(fruits)

print("First Fruit:", fruits[0])
print("Last Fruit:", fruits[-1])
# Out:
# Fruit List:
# ['Apple', 'Banana', 'Mango', 'Orange']
# First Fruit: Apple
# Last Fruit: Orange

# %%
student = ("Anushree", 22, "Data Science")

print(student)
print("Name:", student[0])
# Out:
# ('Anushree', 22, 'Data Science')
# Name: Anushree

# %%
student_info = {
    "Name": "Anushree",
    "Age": 22,
    "Course": "Data Science"
}

print(student_info)
print("Course:", student_info["Course"])
# Out:
# {'Name': 'Anushree', 'Age': 22, 'Course': 'Data Science'}
# Course: Data Science

# %%
numbers = {1,2,3,4,5,5,5,3}

print(numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
def greet(name):
    print("Hello", name)

greet("Anushree")
# Out:
# Hello Anushree

# %%
square = lambda x: x*x

print(square(5))
# Out:
# 25

# %%
def factorial(n):

    if n == 1:
        return 1

    return n * factorial(n-1)

print(factorial(5))
# Out:
# 120

# %%
squares = [x*x for x in range(1,6)]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
data = [10, 20, 20, 30, 40, 40, 50]

clean_data = list(set(data))

print("Original Data:", data)
print("Clean Data:", clean_data)
# Out:
# Original Data: [10, 20, 20, 30, 40, 40, 50]
# Clean Data: [40, 10, 50, 20, 30]

# %%
numbers = [10, 15, 20, 25, 30, 35]

filtered = [x for x in numbers if x > 20]

print(filtered)
# Out:
# [25, 30, 35]

# %% [markdown]
# # Week 2 Summary
#
# Topics Learned
#
# - Lists
# - Tuples
# - Dictionaries
# - Sets
# - Functions
# - Lambda Functions
# - Recursion
# - List Comprehension
#
# Client Project
#
# - Removed duplicate values from data
# - Filtered data using conditions

# %% [markdown]
# # Week 3 - NumPy and Pandas for Data Manipulation

# %%
import numpy as np
import pandas as pd

# %%
arr = np.array([10, 20, 30, 40, 50])

print("Array:", arr)
print("Mean:", arr.mean())
print("Maximum:", arr.max())
print("Minimum:", arr.min())
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Maximum: 50
# Minimum: 10

# %%
df = pd.read_csv("../datasets/student_data.csv")

df
# Out:
#    StudentID  Math  Science  English  Attendance
# 0          1    85       90       88          95
# 1          2    78       82       80          88
# 2          3    92       94       91          98
# 3          4    65       70       68          80
# 4          5    88       85       90          92
# 5          6    75       78       72          85
# 6          7    95       96       94          99
# 7          8    60       65       62          75
# 8          9    82       84       86          90
# 9         10    89       91       87          94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   10 non-null     int64
#  1   Math        10 non-null     int64
#  2   Science     10 non-null     int64
#  3   English     10 non-null     int64
#  4   Attendance  10 non-null     int64
# dtypes: int64(5)
# memory usage: 528.0 bytes

# %%
df.describe()
# Out:
#        StudentID       Math    Science    English  Attendance
# count   10.00000  10.000000  10.000000  10.000000   10.000000
# mean     5.50000  80.900000  83.500000  81.800000   89.600000
# std      3.02765  11.493476  10.135197  10.881176    7.763161
# min      1.00000  60.000000  65.000000  62.000000   75.000000
# 25%      3.25000  75.750000  79.000000  74.000000   85.750000
# 50%      5.50000  83.500000  84.500000  86.500000   91.000000
# 75%      7.75000  88.750000  90.750000  89.500000   94.750000
# max     10.00000  95.000000  96.000000  94.000000   99.000000

# %%
df.isnull().sum()
# Out:
# StudentID     0
# Math          0
# Science       0
# English       0
# Attendance    0
# dtype: int64

# %%
df["AverageMarks"] = (
    df["Math"] +
    df["Science"] +
    df["English"]
) / 3

df
# Out:
#    StudentID  Math  Science  English  Attendance  AverageMarks
# 0          1    85       90       88          95     87.666667
# 1          2    78       82       80          88     80.000000
# 2          3    92       94       91          98     92.333333
# 3          4    65       70       68          80     67.666667
# 4          5    88       85       90          92     87.666667
# 5          6    75       78       72          85     75.000000
# 6          7    95       96       94          99     95.000000
# 7          8    60       65       62          75     62.333333
# 8          9    82       84       86          90     84.000000
# 9         10    89       91       87          94     89.000000

# %%
top_student = df.loc[df["AverageMarks"].idxmax()]

print(top_student)
# Out:
# StudentID        7.0
# Math            95.0
# Science         96.0
# English         94.0
# Attendance      99.0
# AverageMarks    95.0
# Name: 6, dtype: float64

# %%
print("Average Attendance:", df["Attendance"].mean())
# Out:
# Average Attendance: 89.6

# %%
df_clean = df.copy()

df_clean.fillna(0, inplace=True)

print("Dataset Cleaned Successfully")
# Out:
# Dataset Cleaned Successfully

# %% [markdown]
# # Week 3 Summary
#
# Topics Learned
#
# - NumPy Arrays
# - Pandas DataFrames
# - Loading CSV Files
# - Dataset Statistics
# - Missing Value Detection
# - Feature Creation
#
# Client Project
#
# - Loaded student dataset
# - Checked missing values
# - Calculated average marks
# - Identified top-performing student
# - Created cleaned dataset

# %% [markdown]
# # Week 4 - Data Visualization with Matplotlib and Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Math"], bins=5)

plt.title("Distribution of Math Scores")
plt.xlabel("Math Marks")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Math"], df["Science"])

plt.title("Math vs Science")
plt.xlabel("Math")
plt.ylabel("Science")

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.bar(df["StudentID"], df["Attendance"])

plt.title("Attendance of Students")
plt.xlabel("Student ID")
plt.ylabel("Attendance")

plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#               StudentID      Math   Science   English  Attendance  \
# StudentID      1.000000 -0.030334 -0.092334 -0.087690   -0.141819
# Math          -0.030334  1.000000  0.981975  0.978000    0.984519
# Science       -0.092334  0.981975  1.000000  0.959150    0.995579
# English       -0.087690  0.978000  0.959150  1.000000    0.972311
# Attendance    -0.141819  0.984519  0.995579  0.972311    1.000000
# AverageMarks  -0.069478  0.995872  0.988747  0.988275    0.992708
#
#               AverageMarks
# StudentID        -0.069478
# Math              0.995872
# Science           0.988747
# English           0.988275
# Attendance        0.992708
# AverageMarks      1.000000

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df[["Math","Science","English"]])

plt.title("Marks Distribution")

plt.show()

# %%
print("Student Performance Dashboard Created Successfully")
# Out:
# Student Performance Dashboard Created Successfully

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Math"], bins=5)

plt.title("Distribution of Math Scores")

plt.savefig("../outputs/math_histogram.png")

plt.show()

# %% [markdown]
# # Week 4 Summary
#
# Topics Learned
#
# - Matplotlib
# - Seaborn
# - Histograms
# - Scatter Plots
# - Bar Charts
# - Heatmaps
# - Boxplots
#
# Client Project
#
# - Created Student Performance Dashboard
# - Visualized student marks
# - Analyzed feature correlations
# - Exported plots for reporting

# %% [markdown]
# # Month 1 Internship Completion Summary
#
# Completed Topics
#
# ## Week 1
# - Python Basics
# - Variables
# - Loops
# - Conditions
#
# ## Week 2
# - Data Structures
# - Functions
# - Lambda Functions
# - Recursion
#
# ## Week 3
# - NumPy
# - Pandas
# - Data Cleaning
#
# ## Week 4
# - Data Visualization
# - Matplotlib
# - Seaborn
#
# Project Outcome
#
# Created a Student Performance Analysis project using Python, NumPy, Pandas, Matplotlib, and Seaborn.
